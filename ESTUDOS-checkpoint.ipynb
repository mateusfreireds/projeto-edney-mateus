# %%
lista = []

for i in range(5) :
    n = int(input('TESTE: '))
    lista.append(n)

for i in range(4,-1,-1) :
    print(lista[i])

# %%
'''Faça um programa que receba a temperatura média de cada mês do ano e armazene-as em uma lista.
Após isto, calcule a média anual das temperaturas e mostre todas as temperaturas acima da média anual, e em que mês elas 
ocorreram (mostrar o mês por extenso: 1 – Janeiro, 2 – Fevereiro, . . . ). '''

listames = ['Jan','Fev','Mar','Abr','Mai','Jun','Jul','Ago','Set','Out','Nov','Dez']
listatemp = []
n = 0
o = 0

while n < len(listames):
    o = int(input('TEMP %s :'%(listames[n])))
    listatemp.append(o)
    n = n + 1

for x in range(n):
    print('%s - %s' %(listatemp[x],listames[x]))

# %%
'''Faça um programa para imprimir: 
    1
    2   2
    3   3   3
    .....
    n   n   n   n   n   n  ... n
para um n informado pelo usuário. Use uma função que receba um valor n inteiro e imprima até a n-ésima linha. '''

#solução correta
def funcao_1(n):
    for i in range(1,n+1):
        print((str(i)+ "  "  ) * i )
              
funcao_1(int(input('NUMERO : ')))

# %%
'''Faça um programa para imprimir: 
    1
    1   2
    1   2   3
    .....
    1   2   3   ...  n
para um n informado pelo usuário. Use uma função que receba um valor n inteiro imprima até a n-ésima linha. '''

def fun1(n):
    o = 1
    listan = []
    for i in range(1,n+1):
        for x in range(1,o+1):
            listan.append(str(x))
        print("  ".join(listan))
        listan = []
        o = o + 1
        
fun1(int(input('NÚMERO : ')))

# %%
'''Faça um programa, com uma função que necessite de três argumentos, e que forneça a soma desses três argumentos. '''

def fun1(a,b,c):
    return a + b + c

a = int(input('NÚMERO : '))
b = int(input('NÚMERO : '))
c = int(input('NÚMERO : '))
print(fun1(a,b,c))

# %%
'''Faça um programa, com uma função que necessite de um argumento. A função retorna o valor de caractere ‘P’,
se seu argumento for positivo, e ‘N’, se seu argumento for zero ou negativo. '''

def fun1(n):
    if n > 0:
        return "P"
    else:
        return "N"
print(fun1(int(input('NÚMERO : '))))

# %%
'''Faça um programa com uma função chamada somaImposto. A função possui dois parâmetros formais: taxaImposto, que é 
a quantia de imposto sobre vendas expressa em porcentagem e custo, que é o custo de um item antes do imposto. 
A função “altera” o valor de custo para incluir o imposto sobre vendas. '''

def somaimposto(taxaImposto,custo):
    return (1 + (taxaImposto/100))*custo

a = int(input('Imposto % : '))
b = int(input('Custo : '))

print(somaimposto(a,b))

# %%
'''Faça um programa que converta da notação de 24 horas para a notação de 12 horas. Por exemplo, o programa deve converter
14:25 em 2:25 P.M. A entrada é dada em dois inteiros. Deve haver pelo menos duas funções: uma para fazer a conversão e uma para
a saída. Registre a informação A.M./P.M. como um valor ‘A’ para A.M. e ‘P’ para P.M. Assim, a função para efetuar as conversões
terá um parâmetro formal para registrar se é A.M. ou P.M. Inclua um loop que permita que o usuário repita esse cálculo para
novos valores de entrada todas as vezes que desejar. '''

def conversor(hh,mm):
    if hh > 24 or mm < 0 or mm > 60 or hh < 0:
        return " " , "ERRO"
    elif hh > 12 and hh <= 24:
        return str(hh - 12) + " : " + str(mm), "P"
    elif hh <= 12 and hh > 0:
        return str(hh) + " : " + str(mm), "A"


def mostrador(hh,mm):
    a , b = conversor(hh,mm)
    if b == "P":
        return str(a) + "  P.M"
    elif b == "A":
        return str(a) + "  A.M"
    else:
        return "HORA INVÁLIDA"

x = 1
while x == 1:
    hh = int(input("HORA : "))
    mm = int(input("MINUTO : "))
    print(mostrador(hh,mm))

# %%
'''Faça um programa que use a função valorPagamento para determinar o valor a ser pago por uma prestação de uma conta.
O programa deverá solicitar ao usuário o valor da prestação e o número de dias em atraso e passar estes valores para a
função valorPagamento, que calculará o valor a ser pago e devolverá este valor ao programa que a chamou. O programa
deverá então exibir o valor a ser pago na tela. Após a execução o programa deverá voltar a pedir outro valor de
prestação e assim continuar até que seja informado um valor igual a zero para a prestação. Neste momento o programa
deverá ser encerrado, exibindo o relatório do dia, que conterá a quantidade e o valor total de prestações pagas no
dia. O cálculo do valor a ser pago é feito da seguinte forma. Para pagamentos sem atraso, cobrar o valor da
prestação. Quando houver atraso, cobrar 3% de multa, mais 0,1% de juros por dia de atraso. '''

def valorPagamento(vlpr,datr):
    if datr > 0 :
        return (1+(0.03 + (0.001 * datr))) * vlpr
    else:
        return vlpr

listavl = []
d = 0
a = 1
while a == 1:
    b = int(input('VALOR PARCELA : '))
    if b > 0:
        c = int(input('DIAS ATRASO : '))
        print(valorPagamento(b,c))
        listavl.append(valorPagamento(b,c))
        d = d + 1
    else:
        a = 0

print("RESUMO DIA : \n PARCELAS PAGAS : %s \n VL PAGO : %s" %(d , sum(listavl)))

# %%
'''
Faça uma função que informe a quantidade de dígitos de um determinado número inteiro informado. '''

def numeroDig(n):
    o = 1
    while n >= 10:
        n = n / 10
        o = o + 1
    return o

v = int(input('NÚMERO : '))
print(numeroDig(v))

# %%
'''Reverso do número. Faça uma função que retorne o reverso de um número inteiro informado. Por exemplo: 127 -> 721. '''
def numeroRev(n):
    listarev = []
    while int(n) >= 10:
        o = n % 10
        listarev.append(str(o))
        n = int(n / 10)
    listarev.append(str(n))
    return "".join(listarev)

x = int(input('NUMERO : '))
print(numeroRev(x))
# Out:
# NUMERO : 287
# 782

# %%
import os
import pymysql
import time
import pandas as pd
from tkinter import *


#Parâmetros de conexão com o banco de dados mysql usando a livraria externa "pymysql"
host = os.getenv('remotemysql.com')
port = os.getenv('3306')
user = os.getenv('k7NQJfCfAz')
password = os.getenv('FGJIFXXq8C')
database = os.getenv('k7NQJfCfAz')

conn = pymysql.connect(
    host='remotemysql.com',
    port=int(3306),
    user="k7NQJfCfAz",
    passwd='FGJIFXXq8C',
    db="k7NQJfCfAz",
    charset='utf8mb4')
##

#Aplicação de autenticação
class Autenticador:
    def __init__(self, master=None):
        #Estrutura de containers do Autenticador
        self.fontePadrao = ("Arial", "10")
        self.primeiroContainer = Frame(master)
        self.primeiroContainer["pady"] = 10
        self.primeiroContainer.pack()
  
        self.segundoContainer = Frame(master)
        self.segundoContainer["padx"] = 20
        self.segundoContainer.pack()
  
        self.terceiroContainer = Frame(master)
        self.terceiroContainer["padx"] = 20
        self.terceiroContainer.pack()
  
        self.quartoContainer = Frame(master)
        self.quartoContainer["pady"] = 20
        self.quartoContainer.pack()
        
        self.quintoContainer = Frame(master)
        self.quintoContainer["pady"] = 10
        self.quintoContainer.pack()
        
        #Widgets do Autenticador        
        self.titulo = Label(self.primeiroContainer, text="Dados do usuário")
        self.titulo["font"] = ("Arial", "10", "bold")
        self.titulo.pack()
  
        self.nomeLabel = Label(self.segundoContainer,text="Nome", font=self.fontePadrao)
        self.nomeLabel.pack(side=LEFT)
        
        self.nome = Entry(self.segundoContainer)
        self.nome["width"] = 30
        self.nome["font"] = self.fontePadrao
        self.nome.pack(side=LEFT)
  
        self.senhaLabel = Label(self.terceiroContainer, text="Senha", font=self.fontePadrao)
        self.senhaLabel.pack(side=LEFT)
  
        self.senha = Entry(self.terceiroContainer)
        self.senha["width"] = 30
        self.senha["font"] = self.fontePadrao
        self.senha["show"] = "*"
        self.senha.pack(side=LEFT)
  
        self.autenticar = Button(self.quartoContainer)
        self.autenticar["text"] = "Autenticar"
        self.autenticar["font"] = ("Calibri", "8")
        self.autenticar["width"] = 12
        self.autenticar["command"] = self.verificaSenha
        self.autenticar.pack(side=RIGHT)
        
        self.cadastrar = Button(self.quartoContainer)
        self.cadastrar["text"] = "Cadastrar"
        self.cadastrar["font"] = ("Calibri", "8")
        self.cadastrar["width"] = 12
        self.cadastrar["command"] = self.cadastraUsuario
        self.cadastrar.pack(side=LEFT)
    
        self.mensagem = Label(self.quintoContainer, text="", font=self.fontePadrao)
        self.mensagem.pack()
  
    #Função para autenticar usuário
    def verificaSenha(self):
        self.usuario = self.nome.get()
        senha = self.senha.get()
        listaus = []
        autsenha = pd.read_sql_query("SELECT senha FROM k7NQJfCfAz.autenticador where usuario = %s"%("'"+self.usuario+"'") ,conn)
    
        if str(senha) == str(autsenha.senha.any()):
            command = root.destroy()
        else:
            self.mensagem["text"] = 'Senha incorreta'
            
        
    #Função para cadastrar usuário
    def cadastraUsuario(self):
        usuario = self.nome.get()
        senha = self.senha.get()
        autus = pd.read_sql_query("SELECT usuario FROM k7NQJfCfAz.autenticador", conn)
        maxid = pd.read_sql_query("SELECT max(id) as maxid FROM k7NQJfCfAz.autenticador", conn)
        listaus = []

        for x in range(1,maxid.maxid.item()):
            listaus.append(pd.read_sql_query("SELECT usuario FROM k7NQJfCfAz.autenticador where id = "+str(x)+"", conn).usuario.any())
            
        if usuario in listaus:
            self.mensagem["text"] = "Usuário existente!"
        else:
            with conn.cursor() as cursor:
                cursor.execute("insert into k7NQJfCfAz.autenticador (usuario,senha) values('"+usuario+"','"+senha+"') ")
                conn.commit()
                idusnovo = pd.read_sql_query("SELECT id FROM k7NQJfCfAz.autenticador where usuario = '"+str(usuario)+"'", conn).id.item()
                cursor.execute("insert into k7NQJfCfAz.documentos (id_usuario) values('"+str(idusnovo)+"') ")
            conn.commit()
            self.mensagem["text"] = "Usuário cadastrado"
        
  
root = Tk()
A = Autenticador(root)
root.mainloop()




class Documentos:
    def __init__(self, master=None):
        #definindo variáveis do usuário autenticado
        idus = pd.read_sql_query("SELECT id FROM k7NQJfCfAz.autenticador where usuario = '"+str(A.usuario)+"'", conn).id.item()
        cpfus = pd.read_sql_query("SELECT case when numcpf is null then '' else numcpf end as numcpf  FROM k7NQJfCfAz.documentos where id_usuario ='"+str(idus)+"'", conn).numcpf.item()
        identidadeus = pd.read_sql_query("SELECT case when numidentidade is null then '' else numidentidade end as numidentidade  FROM k7NQJfCfAz.documentos where id_usuario ='"+str(idus)+"'", conn).numidentidade.item()
        cnhus = pd.read_sql_query("SELECT case when numcnh is null then '' else numcnh end as numcnh  FROM k7NQJfCfAz.documentos where id_usuario ='"+str(idus)+"'", conn).numcnh.item()
        titulous = pd.read_sql_query("SELECT case when numtitulo is null then '' else numtitulo end as numtitulo  FROM k7NQJfCfAz.documentos where id_usuario ='"+str(idus)+"'", conn).numtitulo.item()
        
        #estrutura de containers da aplicação Documentos
        self.fonte = ("Arial", "10")
        self.container1 = Frame(master)
        self.container1["pady"] = 10
        self.container1.pack()
        
        self.container2 = Frame(master)
        self.container2["padx"] = 20
        self.container2["pady"] = 5
        self.container2.pack()
        
        self.container3 = Frame(master)
        self.container3["padx"] = 20
        self.container3["pady"] = 5
        self.container3.pack()
        
        self.container4 = Frame(master)
        self.container4["padx"] = 20
        self.container4["pady"] = 5
        self.container4.pack()
        
        self.container5 = Frame(master)
        self.container5["padx"] = 20
        self.container5["pady"] = 5
        self.container5.pack()
        
        self.container6 = Frame(master)
        self.container6["padx"] = 20
        self.container6["pady"] = 10
        self.container6.pack()
        
        self.container7 = Frame(master)
        self.container7["pady"] = 15
        self.container7.pack()
  
        
        #Widgets da aplicação Documentos
        self.titulo = Label(self.container1, text="Documentos do "+A.usuario+" :")
        self.titulo["font"] = ("Calibri", "9", "bold")
        self.titulo.pack ()
        
        self.lblcpf = Label(self.container2, text="CPF:", font=self.fonte, width=10)
        self.lblcpf.pack(side=LEFT)
          
        self.txtcpf = Entry(self.container2)
        self.txtcpf["width"] = 25
        self.txtcpf["font"] = self.fonte
        self.txtcpf.pack(side=LEFT)
        self.txtcpf.insert(INSERT,str(cpfus))
        
        self.lblidentidade = Label(self.container3, text="Identidade:", font=self.fonte, width=10)
        self.lblidentidade.pack(side=LEFT)
  
        self.txtidentidade = Entry(self.container3)
        self.txtidentidade["width"] = 25
        self.txtidentidade["font"] = self.fonte
        self.txtidentidade.pack(side=LEFT)
        self.txtidentidade.insert(INSERT,str(identidadeus))
  
        self.lblcnh = Label(self.container4, text="CNH:", font=self.fonte, width=10)
        self.lblcnh.pack(side=LEFT)
  
        self.txtcnh = Entry(self.container4)
        self.txtcnh["width"] = 25
        self.txtcnh["font"] = self.fonte
        self.txtcnh.pack(side=LEFT)
        self.txtcnh.insert(INSERT,str(cnhus))
        
        self.lbltitulo= Label(self.container5, text="Titulo:", font=self.fonte, width=10)
        self.lbltitulo.pack(side=LEFT)
  
        self.txttitulo = Entry(self.container5)
        self.txttitulo["width"] = 25
        self.txttitulo["font"] = self.fonte
        self.txttitulo.pack(side=LEFT)
        self.txttitulo.insert(INSERT,str(titulous))
        
        self.atualizar = Button(self.container6)
        self.atualizar["text"] = "Atualizar"
        self.atualizar["font"] = ("Calibri", "8")
        self.atualizar["width"] = 12
        self.atualizar["command"] = self.atualizaUsuario
        self.atualizar.pack(side=LEFT)

        self.lblmsg = Label(self.container7, text="")
        self.lblmsg["font"] = ("Verdana", "9", "italic")
        self.lblmsg.pack()
        
        
        
    #função que atualiza os documentos de acordo com os entrys    
    def atualizaUsuario(self) :
        idus = pd.read_sql_query("SELECT id FROM k7NQJfCfAz.autenticador where usuario = '"+str(A.usuario)+"'", conn).id.item()
        cpfus = self.txtcpf.get()
        identidadeus = self.txtidentidade.get()
        cnhus = self.txtcnh.get()
        titulous = self.txttitulo.get()
        
        with conn.cursor() as cursor:
            iddocumentos = pd.read_sql_query("SELECT id FROM k7NQJfCfAz.documentos where id_usuario = '"+str(idus)+"'", conn).id.item()
            cursor.execute("UPDATE k7NQJfCfAz.documentos set numidentidade = '"+str(identidadeus)+"' where id = '"+str(iddocumentos)+"'")
            cursor.execute("UPDATE k7NQJfCfAz.documentos set numcnh = '"+str(cnhus)+"' where id = '"+str(iddocumentos)+"'")
            cursor.execute("UPDATE k7NQJfCfAz.documentos set numtitulo = '"+str(titulous)+"' where id = '"+str(iddocumentos)+"'")
            cursor.execute("UPDATE k7NQJfCfAz.documentos set numcpf = '"+str(cpfus)+"' where id = '"+str(iddocumentos)+"'")
            conn.commit()
        self.lblmsg["text"] = "Documentos atualizados!"
                                
            
        
 
root2 = Tk()
B = Documentos(root2)
root2.mainloop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-17ca144c9fc3> in <module>
#     249
#     250 root2 = Tk()
# --> 251 B = Documentos(root2)
#     252 root2.mainloop()
#
# <ipython-input-5-17ca144c9fc3> in __init__(self, master)
#     132     def __init__(self, master=None):
#     133         #definindo variáveis do usuário autenticado
# --> 134         idus = pd.read_sql_query("SELECT id FROM k7NQJfCfAz.autenticador where usuario = '"+str(A.usuario)+"'", conn).id.item()
#     135         cpfus = pd.read_sql_query("SELECT case when numcpf is null then '' else numcpf end as numcpf  FROM k7NQJfCfAz.documentos where id_usuario ='"+str(idus)+"'", conn).numcpf.item()
# ...

# %%
import os
import pymysql
import pandas as pd
from tkinter import *

host = os.getenv('remotemysql.com')
port = os.getenv('3306')
user = os.getenv('k7NQJfCfAz')
password = os.getenv('FGJIFXXq8C')
database = os.getenv('k7NQJfCfAz')

conn = pymysql.connect(
    host='remotemysql.com',
    port=int(3306),
    user="k7NQJfCfAz",
    passwd='FGJIFXXq8C',
    db="k7NQJfCfAz",
    charset='utf8mb4')

'''listaus = []
maxid = pd.read_sql_query("SELECT max(id) as maxid FROM k7NQJfCfAz.autenticador", conn)
for x in range(1,maxid.maxid.all()):
    listaus.append(pd.read_sql_query("SELECT usuario FROM k7NQJfCfAz.autenticador where id = "+str(x)+"", conn).usuario.all())
'''        

maxid = pd.read_sql_query("SELECT max(id) as maxid FROM k7NQJfCfAz.autenticador", conn)
print(maxid.maxid.item())
